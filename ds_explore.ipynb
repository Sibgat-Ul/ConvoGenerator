# %%
from datasets import load_dataset

# bn_speech_ds = load_dataset("json", data_files="./bengali_speech_dataset/metadata.jsonl")
# bn_speech_ds = load_dataset("json", data_files="./generated_completions.json", split="train")
bn_speech_ds = load_dataset("parquet", data_files="./bengali_annoted_ds/train.parquet")
bn_speech_ds
# Out:
# Generating train split: 0 examples [00:00, ? examples/s]
# DatasetDict({
#     train: Dataset({
#         features: ['conversation_id', 'conversation', 'num_turns', 'audio_files', 'success'],
#         num_rows: 4810
#     })
# })

# %%
bn_speech_ds["train"][0]
# Out:
# {'conversation_id': 'conversation_000000',
#  'conversation': [{'audio': 'wav/conversation_000000/turn_000_user.wav',
#    'content': 'আচ্ছা, কেমন আছো? আমার মনে হয় একটু গেম নিয়ে কথা বলা যায়, তুমি কি ভিডিও গেম বা বোর্ড গেম খেলতে পছন্দ করো?',
#    'role': 'user',
#    'unit': {'global_ids': [2631,
#      3795,
#      3826,
#      3523,
#      69,
#      1116,
#      162,
#      2780,
#      918,
#      2366,
#      2351,
#      1653,
#      758,
#      3616,
#      3251,
#      3549,
#      3575,
#      4021,
#      1722,
#      2295,
#      1223,
#      1767,
#      1021,
#      1860,
#      2134,
#      3011,
#      3539,
#      3277,
#      1057,
#      1166,
#      1406,
#      2772],
#     'semantic_ids': [5668,
#      1130,
#      7230,
#      2192,
#      2613,
#      6203,
#      3594,
#      1903,
#      1961,
#      7334,
#      883,
#      4847,
#      3904,
#      6175,
#      5715,
#      2230,
#      816,
#      4326,
#      5564,
#      7943,
#      2518,
# ...

# %%
bn_speech_ds[0]
# Out:
# {'transcription': 'তারপর চার মাস তিনি ছিলেন কেন্দ্রীয় গোয়েন্দা সংস্থার তত্বাবধানে এক নিরাপদ জায়গায় ',
#  'file_path': '/subakko/part5/wav5/e4/TNM22_MESBA_page_257-258_5_5_Labeled_by_Tomal-20.wav',
#  'lm_response': 'আপনার প্রশ্নটি স্পষ্ট নয়। আপনি যদি এই বাক্যটি নিয়ে অন্য কিছু জানতে চান তবে জিজ্ঞাসা করতে পারেন।'}

# %%
bn_speech_ds["train"][0]
# Out:
# {'conversation_id': 'conversation_000000',
#  'conversation': [{'role': 'user',
#    'content': 'আচ্ছা, কেমন আছো? আমার মনে হয় একটু গেম নিয়ে কথা বলা যায়, তুমি কি ভিডিও গেম বা বোর্ড গেম খেলতে পছন্দ করো?',
#    'audio': 'wav/conversation_000000/turn_000_user.wav'},
#   {'role': 'assistant',
#    'content': 'আরে ! আমি ভালো আছি, তুমি কেমন আছো? গেম নিয়ে কথা বলতে চাও? দারুণ! হ্যাঁ, আমি ভিডিও গেম খেলতে খুব পছন্দ করি। বিশেষ করে - আমার খুব প্রিয়। যেমন, বা তিন - এগুলো খেলতে আমি ঘণ্টার পর ঘণ্টা কাটিয়ে দিতে পারি! আর তুমি? কী ধরনের গেম খেলতে ভালো লাগে? বোর্ড গেম খেলো কখনো? যদি হ্যাঁ, তাহলে কোন ধরনের বোর্ড গেম তোমার পছন্দের? নাকি কার্ড গেমও তোমার ভালো লাগে? আর তোমার সপ্তাহান্তে কি করার আছে? কোনো প্ল্যান করেছো নাকি?',
#    'audio': 'wav/conversation_000000/turn_001_assistant.wav'}],
#  'num_turns': 2,
#  'audio_files': ['wav/conversation_000000/turn_000_user.wav',
#   'wav/conversation_000000/turn_001_assistant.wav'],
#  'success': True}

# %%
from IPython.display import Audio
import torchaudio
from pathlib import Path

audio_path = Path("./bengali_speech_dataset") / bn_speech_ds["train"][0]["conversation"][0]["audio"]
example = torchaudio.load(audio_path)
example
# Out:
# (tensor([[-0.0003, -0.0003, -0.0003,  ..., -0.0004, -0.0005, -0.0005]]), 16000)

# %%
audio, sr = example
Audio(audio.numpy(), rate=sr)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
from huggingface_hub import HfApi, login

login("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")

api = HfApi()

api.upload_large_folder(
    folder_path="./bengali_speech_dataset",
    repo_id="InteliLab/ban_speech_Spark",
    repo_type="dataset"
)
# Out:
# Note: Environment variable`HF_TOKEN` is set and is the current active token independently from the token you've just configured.
# Recovering from metadata files:   0%|          | 0/19072 [00:00<?, ?it/s]
# ---------- 2026-05-06 00:27:34 (0:00:00) ----------
# Files:   hashed 19071/19072 (22.2G/22.2G) | pre-uploaded: 19071/19071 (22.2G/22.2G) (+1 unsure) | committed: 19071/19072 (22.2G/22.2G) | ignored: 0
# Workers: hashing: 1 | get upload mode: 0 | pre-uploading: 0 | committing: 0 | waiting: 21
# ---------------------------------------------------
# Processing Files (0 / 0): |          |  0.00B /  0.00B
# New Data Upload: |          |  0.00B /  0.00B
# Processing Files (0 / 0): |          |  0.00B /  0.00B
# New Data Upload: |          |  0.00B /  0.00B
